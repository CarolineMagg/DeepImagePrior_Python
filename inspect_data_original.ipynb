# %% [markdown]
# # Inspect original data
#
# original data comes from the DIP Paper:
# * FT (denoising)
# * snail (jpg compression denoising)
#
# * zebra (super resolution)
#
# * kate (inpainting)
# * vase (inpainting)
# * library (inpainting)

# %%
data_path = "data/original"

# %%
import sys
sys.path.append("src/utils")

# %%
from src.utils.data_processing import *
from src.utils.data_plotting import *

# %% [markdown]
# # Denoising data

# %%
img = load_image(os.path.join(data_path,"F16_GT.png"))
image_information(img)
plt.imshow(img)
plt.show()
# Out:
# dtype:  float32 , type:  <class 'numpy.ndarray'>
# size:  (512, 512, 3) , range: 0.0 - 0.9176470637321472

# %%
img = load_image(os.path.join(data_path,"snail.jpg"))
image_information(img)
plt.imshow(img)
plt.show()
# Out:
# dtype:  float32 , type:  <class 'numpy.ndarray'>
# size:  (256, 384, 3) , range: 0.0 - 1.0

# %% [markdown]
# # Super Resolution

# %%
img = load_image(os.path.join(data_path,"zebra_GT.png"))
image_information(img)
plt.imshow(img)
plt.show()
# Out:
# dtype:  float32 , type:  <class 'numpy.ndarray'>
# size:  (384, 576, 3) , range: 0.0 - 1.0

# %%
img = load_image(os.path.join(data_path,"zebra_crop.png"))
image_information(img)
plt.imshow(img)
plt.show()
# Out:
# dtype:  float32 , type:  <class 'numpy.ndarray'>
# size:  (160, 256, 3) , range: 0.0 - 1.0

# %% [markdown]
# # Inpainting

# %%
img = load_image(os.path.join(data_path,"kate.png"))
image_information(img)
plt.imshow(img)
plt.show()
# Out:
# dtype:  float32 , type:  <class 'numpy.ndarray'>
# size:  (512, 512, 3) , range: 0.0 - 1.0

# %%
img = load_image(os.path.join(data_path,"kate_mask.png"))
image_information(img)
plt.imshow(img)
plt.show()
# Out:
# dtype:  float32 , type:  <class 'numpy.ndarray'>
# size:  (512, 512, 3) , range: 0.0 - 1.0

# %%
img = load_image(os.path.join(data_path,"library.png"))
image_information(img)
plt.imshow(img)
plt.show()
# Out:
# dtype:  float32 , type:  <class 'numpy.ndarray'>
# size:  (448, 704, 3) , range: 0.0 - 1.0

# %%
img = load_image(os.path.join(data_path,"library_mask.png"))
image_information(img)
plt.imshow(img)
plt.show()
# Out:
# dtype:  float32 , type:  <class 'numpy.ndarray'>
# size:  (448, 704, 3) , range: 0.0 - 1.0

# %%
img = load_image(os.path.join(data_path,"vase.png"))
image_information(img)
plt.imshow(img)
plt.show()
# Out:
# dtype:  float32 , type:  <class 'numpy.ndarray'>
# size:  (320, 320, 3) , range: 0.0 - 1.0

# %%
img = load_image(os.path.join(data_path,"vase_mask.png"))
image_information(img)
plt.imshow(img)
plt.show()
# Out:
# dtype:  float32 , type:  <class 'numpy.ndarray'>
# size:  (320, 320, 3) , range: 0.0 - 1.0
